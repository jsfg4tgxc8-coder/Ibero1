# %% [markdown]
# <a href="https://colab.research.google.com/github/jsfg4tgxc8-coder/Ibero1/blob/main/semaforo_colores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
color=input("pon un color")
if color=="verde":
  print("avanzar")
elif color=="amarillo":
 print("precaucion")
elif color=="rojo":
 print("alto")
# Out:
# pon un colorverde
# avanzar
