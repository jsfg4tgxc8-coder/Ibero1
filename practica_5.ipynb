# %% [markdown]
# <a href="https://colab.research.google.com/github/jsfg4tgxc8-coder/Ibero1/blob/main/practica_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=int(input("ingresa la tabla de multiplicar: "))

for a in range (1,11):
   print(f"3 x {a}={a*3}")
# Out:
# ingresa la tabla de multiplicar: 3
# 3 x 1=3
# 3 x 2=6
# 3 x 3=9
# 3 x 4=12
# 3 x 5=15
# 3 x 6=18
# 3 x 7=21
# 3 x 8=24
# 3 x 9=27
# 3 x 10=30
