# %% [markdown]
# <a href="https://colab.research.google.com/github/jsfg4tgxc8-coder/Ibero1/blob/main/edad_12_a_65.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=int(input("cual es la edad"))
if a < 12:
  print("niño o niña")
elif a>=12 and a <= 17:
  print("eres un adolescente")
elif a>=18 and a <= 64:
  print ("eres un adulto")
elif a>=65:
 print("eres un viejo")
# Out:
# cual es la edad70
# eres un viejo
