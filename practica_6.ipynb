# %% [markdown]
# <a href="https://colab.research.google.com/github/jsfg4tgxc8-coder/Ibero1/blob/main/practica_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
usuario=input("ingresa el ususario:")
password=input("ingresa el password:")

while usuario!="ericktr" and password!="havoc":

  usuario=input("ingresa el ususario:")
  password=input("ingresa el password:")

print("bienvenido erick")
