# %% [markdown]
# <a href="https://colab.research.google.com/github/jsfg4tgxc8-coder/Ibero1/blob/main/calificacion_%3D70.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=int(input("ingresa su calificacion "))
if a >=70:
 print("felicidades aaprobo")
 print(a)
elif a<70 and a>50:
 print("segunda oportunidad")
else:
  print("reprobado")
# Out:
# ingresa su calificacion 80
# felicidades aaprobo
# 80
