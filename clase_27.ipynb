# %%
a=int(input("ingresa el numero1:"))
b=int(input("ingresa el numero2:"))
c=a+b
if(c==10):
# Out:
#   File "/tmp/ipython-input-2245374002.py", line 5
#
#     ^
# SyntaxError: incomplete input

# %%
a=int(input("ingresa el numero 1:"))
b=int(input("ingresa el numero 2:"))
c=(a*b)
# Out:
# ingresa el numero 1:5
# ingresa el numero 2:10
